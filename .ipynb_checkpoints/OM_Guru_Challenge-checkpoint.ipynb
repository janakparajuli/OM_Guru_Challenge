# %%
#!pip install matplotlib_scalebar

# %%
import osmnx as ox
import matplotlib.pyplot as plt
from matplotlib_scalebar.scalebar import ScaleBar
import matplotlib.patches as mpatches

# %%
# Define the area of interest
place_name = "San Francisco, California, USA"

# %%
# Get the green spaces data
green_tags = {'leisure': ['park', 'garden'], 'natural': ['wood', 'tree_row', 'scrub'], 'landuse': ['forest', 'grass']}
greenspaces = ox.geometries_from_place(place_name, green_tags)
 
# Get the water features data 
water_tags = {'natural': ['water'], 'waterway': True}
water = ox.geometries_from_place(place_name, water_tags)

# Get the urban features data
urban_tags = {'building': True, 'highway': True}
urban = ox.geometries_from_place(place_name, urban_tags)
# Out:
# C:\Users\janak\AppData\Local\Temp\ipykernel_6960\3668886666.py:3: FutureWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in the v2.0.0 release. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   greenspaces = ox.geometries_from_place(place_name, green_tags)
# C:\Users\janak\AppData\Local\Temp\ipykernel_6960\3668886666.py:7: FutureWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in the v2.0.0 release. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   water = ox.geometries_from_place(place_name, water_tags)
# ...

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(12, 12))

# Plot green spaces
greenspaces.plot(ax=ax, color='green', alpha=0.5, edgecolor='darkgreen')

# Plot water features
water.plot(ax=ax, color='blue', alpha=0.5, edgecolor='darkblue')

# Plot urban features
#urban.plot(ax=ax, color='gray', alpha=0.5, edgecolor='black')

# Add grid lines
ax.grid(True, which='both', color='lightgrey', linewidth=0.5)

# Add a scale bar
scalebar = ScaleBar(1, location='lower right')
ax.add_artist(scalebar)

# Add a north arrow
x, y, arrow_length = 0.95, 0.95, 0.05
ax.annotate('N', xy=(x, y), xytext=(x, y-arrow_length),
            arrowprops=dict(facecolor='black', shrink=0.05),
            ha='center', va='center', fontsize=12, xycoords=ax.transAxes)

# Add a legend
park_patch = mpatches.Patch(color='green', label='Green Spaces')
water_patch = mpatches.Patch(color='blue', label='Water Features')
urban_patch = mpatches.Patch(color='gray', label='Urban Features')
plt.legend(handles=[park_patch, water_patch, urban_patch], loc='upper left')

# Add title and labels
ax.set_title('Green and Urban Spaces in San Francisco', fontsize=16)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
# Out:
# Text(95.22222222222221, 0.5, 'Latitude')

# %%
# Save the map as a PNG file
plt.savefig('./outputs/san_francisco_greenspaces.png', dpi=300)

# Show the plot
plt.show()
